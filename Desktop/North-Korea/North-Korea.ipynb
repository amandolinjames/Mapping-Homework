# %%
import pandas as pd
import geopandas as gpd
import matplotlib
# %matplotlib inline

# %%
missiles=pd.read_excel('/Users/amandajames/Desktop/north_korea_missile_test_database.xlsx')
missiles
# Out:
#       F1       Date Date Entered/Updated Missile Name Missile Type  \
# 0      1 1984-04-09           2016-12-23       Scud-B         SRBM
# 1      2 1984-04-09           2016-12-23       Scud-B         SRBM
# 2      3 1984-04-09           2016-12-23       Scud-B         SRBM
# 3      4 1984-09-01           2016-12-23       Scud-B         SRBM
# 4      5 1984-09-01           2016-12-23       Scud-B         SRBM
# 5      6 1984-09-01           2016-12-23       Scud-B         SRBM
# 6      7 1986-05-01           2016-12-23      Unknown      Unknown
# 7      8 1990-05-01           2016-12-23       Nodong         MRBM
# 8      9 1990-06-01           2016-12-23       Scud-C         SRBM
# 9     10 1991-07-01           2016-12-23       Scud-C         SRBM
# 10    11 1992-06-01           2016-12-23       Nodong         MRBM
# 11    12 1993-05-29           2016-12-23       Nodong         MRBM
# 12    13 1993-05-29           2016-12-23       Scud-C         SRBM
# ...

# %%
missiles
# Out:
#       F1       Date Date Entered/Updated Missile Name Missile Type  \
# 0      1 1984-04-09           2016-12-23       Scud-B         SRBM
# 1      2 1984-04-09           2016-12-23       Scud-B         SRBM
# 2      3 1984-04-09           2016-12-23       Scud-B         SRBM
# 3      4 1984-09-01           2016-12-23       Scud-B         SRBM
# 4      5 1984-09-01           2016-12-23       Scud-B         SRBM
# 5      6 1984-09-01           2016-12-23       Scud-B         SRBM
# 6      7 1986-05-01           2016-12-23      Unknown      Unknown
# 7      8 1990-05-01           2016-12-23       Nodong         MRBM
# 8      9 1990-06-01           2016-12-23       Scud-C         SRBM
# 9     10 1991-07-01           2016-12-23       Scud-C         SRBM
# 10    11 1992-06-01           2016-12-23       Nodong         MRBM
# 11    12 1993-05-29           2016-12-23       Nodong         MRBM
# 12    13 1993-05-29           2016-12-23       Scud-C         SRBM
# ...

# %%
missiles['Facility Name'].value_counts().head().plot(figsize=(20,20), kind='bar')

# %%
missiles.shape
# Out:
# (110, 18)

# %%
missiles['Facility Location'].value_counts()
# Out:
# Kangwon Province, (North Korea)                 32
# Hwadae County, North Hamgyong Province          17
# Kittae Pass, Kangwon Province, (North Korea)    17
# Hwangju,  North Hwanghae province               12
# South Hamgyong province                          8
# South Pyongan Province                           8
# Cholsan County, North Pyongan Province           7
# Kusong, North Pyongan                            5
# North Hwanghae Province                          2
# Unknown                                          1
# Chiha-ri , Kangwon Province, (North Korea)       1
# Name: Facility Location, dtype: int64
